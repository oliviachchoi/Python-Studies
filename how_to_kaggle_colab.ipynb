# %% [markdown]
# <a href="https://colab.research.google.com/github/oliviachchoi/Python-Studies/blob/master/how_to_kaggle_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Kaggle & Google Colab 연결하기
#
# 1. Account 에 들어가서 Create New API Token
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. .json 파일을 google drive로 옮긴다

# %%
# !pip install kaggle

ls -1ha /content/drive/MyDrive/kaggle.json #본인경로로 바꾸기

# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# Permission Warning이 발생하지 않도록 해줍니다.
# !chmod 600 ~/.kaggle/kaggle.json
# 내가 참가한 대회 리스트 확인
# !kaggle competitions list

#Warning: Looks like you're using an outdated API version, please consider updating 나왔을 때 코드
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %%
#원하는 competition download
#kaggle site에 api나와있음 
# !kaggle competitions download -c dogs-vs-cats

# %%
#download 된 파일 확인
# !ls

# %%
#다운 받은 파일 unzip까지 하면 된다!
# !unzip /content/dogs-vs-cats.zip
# !unzip /content/train.zip
# !unzip test1.zip
